# %%
from bs4 import BeautifulSoup
import cfscrape

# %%
scraper = cfscrape.create_scraper(delay=100)

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
url = 'https://www.novelupdates.com/novelslisting/?st=1&pg=1'
page = scraper.get(url, headers=headers)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
driver = webdriver.Chrome(options=options)
driver.get(url)
content = driver.page_source
driver.quit()

# %%
content
# Out:
# '<html class="no-touch" lang="en-US"><head><meta http-equiv="origin-trial" content="">\n\t<meta charset="UTF-8">\n\t<title>Series Listing - Novel Updates</title>\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n\t<meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE">\n    <meta name="referrer" content="unsafe-url">\n\n\t    <link rel="apple-touch-icon" href="/appicon.png">\n   \n<!-- UniConsent Cookies Consent Notice start -->\n<script type="text/javascript" async="" src="https://www.gstatic.com/recaptcha/releases/DH3nyJMamEclyfe-nztbfV8S/recaptcha__en.js" crossorigin="anonymous" integrity="sha384-RFB9oVlvTplM2seWHBz+PsmThT1DmbvbuROpMMcARnCHL3Ko4+efp
# ...

# %%
response
# Out:
# <Response [403]>

# %%
page
# Out:
# <Response [403]>

# %%
import requests
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [403]>

# %%
session = requests.Session()
session.headers.update(headers)

# %%
initial_response = session.get(url)

# 使用处理过的 Cookies 发送后续请求
response = session.get(url)

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131}button,html{font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}body a{color:#fff}body a:hover{color:#ee730a;text-decoration:underline}body .lds-ring div{border-color:#999 transparent transparent}body .font-red{color:#b20f03}body .pow-button{background-color:#4693ff;color:#1d1d1d}body #challenge-success-text{background-image:url(data:image/svg+xml;base64,...)}body #chall
# ...

# %%
soup = BeautifulSoup(content, 'html.parser')
dig_pag = soup.find('div', attrs={'class': 'digg_pagination'})
max_page = max([int(a.text) for a in dig_pag.find_all('a') if a.text.isdigit()])

# %%
max_page
# Out:
# 100
